# %%
import sys
import os
import pandas as pd
sys.path.append('../../../py_pkg')
import platform_designer as qpd
import pd_ip.pd_ip as pd_ip
from pd_ip.custom_ips import niosv_aes
import pd_ip.quartus_ips as quartus_ips
from analysis import tunable_tdc_sweeper as tts
import time

# %%
# import Quartus Platform Designer system as instance objects
sopcinfo_header = os.path.abspath("../../../../EXPERIMENTS/quartus_projects/niosv_aes/qsys_headers/hps_0.h")
pd_0 = qpd.pd_system("u0", [sopcinfo_header], 0xC0000000, "/dev/mem")
# initialize all modules and setup MMIO
pd_0.initialize(True)
# Out:
# Imported from /root/PL-Sensor-Intel/EXPERIMENTS/quartus_projects/niosv_aes/qsys_headers/hps_0.h
# COMPONENT_NAME: theta_pll_reconfig
# 	COMPONENT_TYPE : altera_pll_reconfig
# 	COMPONENT_NAME : theta_pll_reconfig
# 	BASE : 0
# 	SPAN : 256
# 	END : 255
# COMPONENT_NAME: DMA_to_SDRAM
# 	CSR_COMPONENT_TYPE : altera_msgdma
# 	COMPONENT_TYPE : altera_msgdma
# 	CSR_COMPONENT_NAME : DMA_to_SDRAM
# 	CSR_BASE : 64
# 	CSR_SPAN : 32
# 	CSR_END : 95
# 	CSR_IRQ : 1
# 	CSR_BURST_ENABLE : 1
# 	CSR_BURST_WRAPPING_SUPPORT : 1
# 	CSR_CHANNEL_ENABLE : 0
# 	CSR_CHANNEL_ENABLE_DERIVED : 0
# 	CSR_CHANNEL_WIDTH : 8
# 	CSR_DATA_FIFO_DEPTH : 2048
# 	CSR_DATA_WIDTH : 256
# 	CSR_DESCRIPTOR_FIFO_DEPTH : 64
# 	CSR_DMA_MODE : 2
# 	CSR_ENHANCED_FEATURES : 0
# 	CSR_ERROR_ENABLE : 0
# 	CSR_ERROR_ENABLE_DERIVED : 0
# 	CSR_ERROR_WIDTH : 8
# 	CSR_MAX_BURST_COUNT : 8
# 	CSR_MAX_BYTE : 65536
# 	CSR_MAX_STRIDE : 1
# 	CSR_PACKET_ENABLE : 0
# 	CSR_PACKET_ENABLE_DERIVED : 0
# 	CSR_PREFETCHER_ENABLE : 0
# ...

# %%
# setup DMA *TODO* convert to python module - currently a C driver
dma = os.open("/dev/msgdma_tdc", os.O_RDONLY)
pd_0.pd_ip_insts["DMA_to_SDRAM"].dma_fh=dma

# %%
# Connect reset PIOs to proper instances
pd_0.pd_ip_insts["theta_pll_reconfig"].reset_pio = pd_0.pd_ip_insts["theta_pll_reset_pio"]
pd_0.pd_ip_insts["phi_pll_reconfig"].reset_pio = pd_0.pd_ip_insts["phi_pll_reset_pio"]
pd_0.pd_ip_insts["pulsegenerator"].reset_pio = pd_0.pd_ip_insts["tdc_reset_pio"]
# Connect locked PIOs to PLLs
pd_0.pd_ip_insts["theta_pll_reconfig"].locked_pio = pd_0.pd_ip_insts["theta_locked"]
pd_0.pd_ip_insts["phi_pll_reconfig"].locked_pio = pd_0.pd_ip_insts["phi_locked"]
# Configure PLL number of outputs
pd_0.pd_ip_insts["theta_pll_reconfig"].num_out = 2
pd_0.pd_ip_insts["phi_pll_reconfig"].num_out = 1

# %%
# Import PLL configs for sweep
theta_pll_configs = "../pll_configs/theta.csv"
theta_cfg_params = pd.read_csv(theta_pll_configs)
phi_pll_configs   = "../pll_configs/phi.csv"
phi_cfg_params = pd.read_csv(phi_pll_configs)

# %%
# Hold pulsegenerator and TDC in reset until PLL is configured
pd_0.pd_ip_insts["pulsegenerator"].hold_reset()

# Hold PLL theta in reset until after phi is reset
pd_0.pd_ip_insts["theta_pll_reconfig"].hold_reset()

# # Initialize phi clock - Mostly to ensure bandwidth setting is correct
pd_0.pd_ip_insts["phi_pll_reconfig"].update_all_50(64, 2, [32], "low", 1, [{"phase_updn":0, "phase_amt":0}])

# # Hold PLL theta in reset until after phi is reset
pd_0.pd_ip_insts["theta_pll_reconfig"].reset_pll()
pd_0.pd_ip_insts["pulsegenerator"].reset()

# %%
# AES has no direct interface, so create an instance manually
niosv_aes_ip_dict = {
    "COMPONENT_NAME" : "niosv_aes",
    "COMPONENT_TYPE" : "niosv_aes",
    "BASE" : 0x000,
    "SPAN" : 0x000,
    "END"  : 0x000
}
pd_0.pd_ip_insts["niosv_aes"] = niosv_aes.niosv_aes(
    ip_dict=niosv_aes_ip_dict, mmio_init=False, periph_mem=pd_0.pd_ip_insts["peripheral_mem"])

# All AES traffic flows through IP-Sync instance, so copy it's MMIO interface
pd_0.pd_ip_insts["ip_sync_niosv"].copy_mmio_ifc(pd_0.pd_ip_insts["niosv_aes"])

# Check AES decrypt
pd_0.pd_ip_insts["niosv_aes"].pre()
pd_0.pd_ip_insts["niosv_aes"].run()
pd_0.pd_ip_insts["niosv_aes"].post()

# Hold SEC Works AES in reset during Theta sweep
pd_0.pd_ip_insts["niosv_aes"].hold_reset()

# %%
# Construct a tdc_sweeper instance
tdc_sweeper = tts.TunableTDCSweeper(
    pd_0.pd_ip_insts["theta_pll_reconfig"], 
    pd_0.pd_ip_insts["phi_pll_reconfig"], 
    pd_0.pd_ip_insts["pulsegenerator"], 
    pd_0.pd_ip_insts["DMA_to_SDRAM"], 
    tdc_len = 128,
    target_ip=pd_0.pd_ip_insts["niosv_aes"])

print(tdc_sweeper.target_ip.print_ip_info())
# Out:
# ######## Begin niosv_aes IP instance data ########
# 	COMPONENT_NAME : niosv_aes
# 	COMPONENT_TYPE : niosv_aes
# 	BASE : 16780288
# 	SPAN : 1024
# 	END : 16781311
# ######### End niosv_aes IP instance data #########
#
# None

# %%
# Sweep theta, collect plot results
# Specify theta sweepe parameters
theta_sweep_params = {
    "delay_lower_bound" : 2200,
    "delay_upper_bound" : 4500,
    "min var prop dist" : 28,
    "max var prop dist" : 36,
    "target rising mu"  : 32
}
time_now = time.strftime("%Y-%m-%d_%H:%M:%S", time.gmtime())
out_fh = f"../../../archived_results/data/niosv_theta_sweep_{time_now}.csv"

# Start theta sweep
tdc_sweeper.sweep_theta(
    theta_cfg_params=theta_cfg_params, 
    theta_samples=2**12, 
    sweep_params=theta_sweep_params, 
    tune_param="mid", 
    sweep_data_fh=out_fh, 
    debug=0)
# Out:
# 100% (374 of 374) |######################| Elapsed Time: 0:01:16 Time:  0:01:16

# %%
# Plot theta sweep results
tdc_sweeper.plot_theta_sweep_results(out_fh)
# Out:
# Arrival delay is 2211.538461538458
# Arrival delay is 2211.538461538458
# Arrival delay is 2211.538461538458
# Arrival delay is 2211.538461538458
# Arrival delay is 2211.538461538458
# Arrival delay is 2211.538461538458

# %%
# Phi sweep

# Specify fast theta tune parameters
theta_sweep_params = {
    "delay_lower_bound" : 2211 + 1075,
    "delay_upper_bound" : 2211 + 1150,
    "target rising mu"  : 64
}

# Start fast theta sweep
tdc_sweeper.pop_tune_theta(
    theta_cfg_params=theta_cfg_params,
    theta_samples=2**14, 
    sweep_params=theta_sweep_params,
    tune_rise=False,
    tuning_param="mid")

print(f"\tRise pop: {tdc_sweeper.tuned_theta_avg_rise}")
print(f"\tFall pop: {tdc_sweeper.tuned_theta_avg_fall}")

time_now = time.strftime("%Y-%m-%d_%H:%M:%S", time.gmtime())
out_fh = f"../../../archived_results/data/niosv_phi_sweep_{time_now}.csv"

# Sweep phi, collect results
bg_results = tdc_sweeper.sweep_phi(phi_cfg_params, 2**14, "bg")
target_results = tdc_sweeper.sweep_phi(phi_cfg_params, 2**14, "target", True)
tdc_sweeper.save_bg_target_data(bg_results, target_results, out_fh)
# Out:
#  50% (190 of 374) |###########           | Elapsed Time: 0:00:00 ETA:   0:00:00
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_560/2281634557.py in <module>
#      14     sweep_params=theta_sweep_params,
#      15     tune_rise=False,
# ---> 16     tuning_param="mid")
#      17
#      18 print(f"\tRise pop: {tdc_sweeper.tuned_theta_avg_rise}")
#
# ~/PL-Sensor-Intel/SW/py_pkg/analysis/tunable_tdc_sweeper.py in pop_tune_theta(self, theta_cfg_params, theta_samples, sweep_params, tune_rise, tuning_param)
#     343                         self.pulsegen.prime(0, max_transfer_samples)
#     344                         # Collect TDC traces and append to samples
# --> 345                         samples = samples + self.dma.get_dma_words(max_transfer_samples, tdc_sample_bytes)
#     346                         theta_samples_temp -= max_transfer_samples
#     347
#
# ...

# %%
phi_sweep_df = pd.read_csv(out_fh)
phi_sweep_dict  = phi_sweep_df.to_dict(orient='list')

# Setup subplots
plt.clf()
fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8) = plt.subplots(8, sharex=True)

target_pll_frequency = 25*10**6
target_pll_period_ps = (1/target_pll_frequency)*10**12
phi_sweep_dict["phi delay (rad) bg"] = []
phi_sweep_dict["phi delay (rad) target"] = []
for delay_bg, delay_tg in zip(phi_sweep_df["phi delay (ps) bg"], phi_sweep_df["phi delay (ps) target"]):
    phi_sweep_dict["phi delay (rad) bg"].append((delay_bg/target_pll_period_ps) * 2 * math.pi)
    phi_sweep_dict["phi delay (rad) target"].append((delay_tg/target_pll_period_ps) * 2 * math.pi)
phase_ticks = [0.125 * n * 2 * math.pi for n in range(17)]

phi_sweep_df = pd.DataFrame.from_dict(phi_sweep_dict)
phi_sweep_df = phi_sweep_df[phi_sweep_df["phi delay (rad) bg"] < 4*math.pi]
phi_sweep_dict = phi_sweep_df.to_dict(orient='list')

plt.sca(ax1)
ax1.clear()
plt.xticks(phase_ticks, ['0', 'π/4', 'π/2', '3π/4', 'π', '5π/4', '3π/2', '7π/2', '2π', '9π/4', '5π/2', '11π/4', '3π', '13π/4', '7π/2', '15π/4', '4π'])
ax1.plot(phi_sweep_dict["phi delay (rad) bg"], phi_sweep_dict['delta mu rise bg'], label=r"$\uparrow\Delta\mu$ BG", linewidth=0.5)
ax1.plot(phi_sweep_dict["phi delay (rad) target"], phi_sweep_dict['delta mu rise target'], label=r"$\uparrow\Delta\mu $ NIOS-V AES", linewidth=0.5)
ax1.legend(loc='upper right')
superset = phi_sweep_dict['delta mu rise bg'] + phi_sweep_dict['delta mu rise target']
bound_0 = max([abs(min(superset)), abs(max(superset))])
ax1.set_ylim([-5, 5])

plt.sca(ax2)
ax2.clear()
plt.xticks(phase_ticks, ['0', 'π/4', 'π/2', '3π/4', 'π', '5π/4', '3π/2', '7π/2', '2π', '9π/4', '5π/2', '11π/4', '3π', '13π/4', '7π/2', '15π/4', '4π'])
ax2.plot(phi_sweep_dict["phi delay (rad) bg"], phi_sweep_dict['diff mu rise'], label=r"$\uparrow\Delta\mu$ diff", linewidth=0.5)
ax2.legend(loc='upper right')
superset = phi_sweep_dict['diff mu rise']
bound_0 = max([abs(min(superset)), abs(max(superset))])
ax2.set_ylim([-1.1*bound_0, 1.1*bound_0])


plt.sca(ax3)
ax3.clear()
plt.xticks(phase_ticks, ['0', 'π/4', 'π/2', '3π/4', 'π', '5π/4', '3π/2', '7π/2', '2π', '9π/4', '5π/2', '11π/4', '3π', '13π/4', '7π/2', '15π/4', '4π'])
ax3.plot(phi_sweep_dict["phi delay (rad) bg"], phi_sweep_dict['var rise bg'], label=r"$\uparrow\sigma$ BG", linewidth=0.5)
ax3.plot(phi_sweep_dict["phi delay (rad) target"], phi_sweep_dict['var rise target'], label=r"$\uparrow\sigma$ NIOS-V AES", linewidth=0.5)
ax3.legend(loc='upper right')
superset = phi_sweep_dict['var rise bg'] + phi_sweep_dict['var rise target']
bound_0 = max([abs(min(superset)), abs(max(superset))])

plt.sca(ax4)
ax4.clear()
plt.xticks(phase_ticks, ['0', 'π/4', 'π/2', '3π/4', 'π', '5π/4', '3π/2', '7π/2', '2π', '9π/4', '5π/2', '11π/4', '3π', '13π/4', '7π/2', '15π/4', '4π'])
ax4.plot(phi_sweep_dict["phi delay (rad) bg"], phi_sweep_dict['diff var rise'], label=r"$\uparrow \sigma$ diff", linewidth=0.5)
ax4.legend(loc='upper right')
superset = phi_sweep_dict['diff var rise']
bound_0 = max([abs(min(superset)), abs(max(superset))])
ax4.set_ylim([0, 3])

plt.sca(ax5)
ax5.clear()
plt.xticks(phase_ticks, ['0', 'π/4', 'π/2', '3π/4', 'π', '5π/4', '3π/2', '7π/2', '2π', '9π/4', '5π/2', '11π/4', '3π', '13π/4', '7π/2', '15π/4', '4π'])
ax5.plot(phi_sweep_dict["phi delay (rad) bg"], phi_sweep_dict['delta mu fall bg'], label=r"$\downarrow\Delta\mu$ BG", linewidth=0.5)
ax5.plot(phi_sweep_dict["phi delay (rad) target"], phi_sweep_dict['delta mu fall target'], label=r"$\downarrow\Delta\mu $ NIOS-V AES", linewidth=0.5)
ax5.legend(loc='upper right')
superset = phi_sweep_dict['delta mu fall bg'] + phi_sweep_dict['delta mu fall target']
bound_0 = max([abs(min(superset)), abs(max(superset))])
ax5.set_ylim([-1.1*bound_0, 1.1*bound_0])


plt.sca(ax6)
ax6.clear()
plt.xticks(phase_ticks, ['0', 'π/4', 'π/2', '3π/4', 'π', '5π/4', '3π/2', '7π/2', '2π', '9π/4', '5π/2', '11π/4', '3π', '13π/4', '7π/2', '15π/4', '4π'])
ax6.plot(phi_sweep_dict["phi delay (rad) bg"], phi_sweep_dict['diff mu fall'], label=r"$\downarrow\Delta\mu$ diff", linewidth=0.5)
ax6.legend(loc='upper right')
superset = phi_sweep_dict['diff mu fall']
bound_0 = max([abs(min(superset)), abs(max(superset))])
ax6.set_ylim([-1.1*bound_0, 1.1*bound_0])

plt.sca(ax7)
ax7.clear()
plt.xticks(phase_ticks, ['0', 'π/4', 'π/2', '3π/4', 'π', '5π/4', '3π/2', '7π/2', '2π', '9π/4', '5π/2', '11π/4', '3π', '13π/4', '7π/2', '15π/4', '4π'])
ax7.plot(phi_sweep_dict["phi delay (rad) bg"], phi_sweep_dict['var fall bg'], label=r"$\downarrow\sigma$ BG", linewidth=0.5)
ax7.plot(phi_sweep_dict["phi delay (rad) target"], phi_sweep_dict['var fall target'], label=r"$\downarrow\sigma$ NIOS-V AES", linewidth=0.5)
ax7.legend(loc='upper right')
superset = phi_sweep_dict['var fall bg'] + phi_sweep_dict['var fall target']
bound_0 = max([abs(min(superset)), abs(max(superset))])

plt.sca(ax8)
ax8.clear()
plt.xticks(phase_ticks, ['0', 'π/4', 'π/2', '3π/4', 'π', '5π/4', '3π/2', '7π/2', '2π', '9π/4', '5π/2', '11π/4', '3π', '13π/4', '7π/2', '15π/4', '4π'])
ax8.plot(phi_sweep_dict["phi delay (rad) bg"], phi_sweep_dict['diff var fall'], label=r"$\downarrow \sigma$ diff", linewidth=0.5)
ax8.legend(loc='upper right')
superset = phi_sweep_dict['diff var fall']
bound_0 = max([abs(min(superset)), abs(max(superset))])
ax8.set_ylim([0, 3])

fig.set_size_inches(20, 10)
fig.savefig(f"/home/tyler/PL-Sensor-Intel/SW/archived_results/plots/{file_name}_phi_sweep.png")
